# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
fm_data_1 = pd.read_excel('./FinModel-DRAFT-012323-TEST.xlsm', sheet_name="TransposedData")
fm_data_2 = pd.read_excel('./FinModel-DRAFT-042623-TEST.xlsm', sheet_name="TransposedData")

# %%
fm_data_1 = fm_data_1.set_index('month')
fm_data_2 = fm_data_2.set_index('month')

# %%
fm_data_1.head()
# Out:
#                               act_fcast           6010   6020         6030  \
# month
# Month                Actual vs Forecast  Gross Payroll  Bonus  Commissions
# 2021-01-01 00:00:00                 Act       74436.68      0            0
# 2021-02-01 00:00:00                 Act       74436.68      0            0
# 2021-03-01 00:00:00                 Act       74436.68      0            0
# 2021-04-01 00:00:00                 Act       93603.35      0            0
#
#                                     6040                  4010        tot_rev  \
# month
# Month                Accrued PTO Expense  Subscription Revenue  Total Revenue
# 2021-01-01 00:00:00                    0                     0              0
# 2021-02-01 00:00:00                    0                     0              0
# 2021-03-01 00:00:00                    0                     0              0
# 2021-04-01 00:00:00                    0                     0              0
#
#                        tot_cogs        cash            op_cflow  ...  \
# month                                                            ...
# Month                Total COGS        Cash  Operating Cashflow  ...
# 2021-01-01 00:00:00           0  1724450.27           -88807.18  ...
# 2021-02-01 00:00:00           0  1636283.73           -88166.54  ...
# 2021-03-01 00:00:00           0  1504234.04          -132049.69  ...
# 2021-04-01 00:00:00     2277.82  1338381.27          -162562.62  ...
#
#                                   exp_randd             exp_payrolltb  \
# month
# Month                Research & Development  Payroll Taxes & Benefits
# 2021-01-01 00:00:00                       0                  12051.12
# 2021-02-01 00:00:00                       0                  10114.05
# 2021-03-01 00:00:00                75588.66                  10114.05
# 2021-04-01 00:00:00                58288.28                  13495.59
#
#                                     exp_depamort            exp_empdev  \
# month
# Month                Depreciation & Amortization  Employee Development
# 2021-01-01 00:00:00                       465.73                     0
# 2021-02-01 00:00:00                       484.67                     0
# 2021-03-01 00:00:00                       484.67                     0
# 2021-04-01 00:00:00                       484.67                     0
#
#                             exp_otherincexp      exp_taxes  headcount  mrr  \
# month
# Month                Other Income & Expense  Taxes Expense  Headcount  MRR
# 2021-01-01 00:00:00                 1231.26              0          0    0
# 2021-02-01 00:00:00                  946.84          495.9          0    0
# 2021-03-01 00:00:00                 1032.49              0          0    0
# 2021-04-01 00:00:00                   907.8              0          0    0
#
#                      arr  cac
# month
# Month                ARR  CAC
# 2021-01-01 00:00:00    0    0
# 2021-02-01 00:00:00    0    0
# 2021-03-01 00:00:00    0    0
# 2021-04-01 00:00:00    0    0
#
# [5 rows x 30 columns]

# %%
plt.fill_between(fm_data_1.index, fm_data_1.loc['2023'].tot_rev, fm_data_2.loc['2023'].tot_rev, color='pink')
plt.plot(fm_data_1.loc['2023'].index.to_numpy(), fm_data_1.loc['2023'].tot_rev.to_numpy(), '--')
plt.plot(fm_data_2.loc['2023'].index.to_numpy(), fm_data_2.loc['2023'].tot_rev.to_numpy(), '--')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3651         try:
# -> 3652             return self._engine.get_loc(casted_key)
#    3653         except KeyError as err:
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2023'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_818/2564629352.py in <module>
# ----> 1 plt.fill_between(fm_data_1.loc['2023'].index, fm_data_1.loc['2023'].tot_rev, fm_data_2.loc['2023'].tot_rev, color='pink')
#       2 plt.plot(fm_data_1.loc['2023'].index.to_numpy(), fm_data_1.loc['2023'].tot_rev.to_numpy(), '--')
#       3 plt.plot(fm_data_2.loc['2023'].index.to_numpy(), fm_data_2.loc['2023'].tot_rev.to_numpy(), '--')
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1101
#    1102             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103             return self._getitem_axis(maybe_callable, axis=axis)
#    1104
#    1105     def _is_scalar_access(self, key: tuple):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1341         # fall thru to straight lookup
#    1342         self._validate_key(key, axis)
# -> 1343         return self._get_label(key, axis=axis)
#    1344
#    1345     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1291     def _get_label(self, label, axis: AxisInt):
#    1292         # GH#5567 this will fail if the label is not present in the axis.
# -> 1293         return self.obj.xs(label, axis=axis)
#    1294
#    1295     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4093                     new_index = index[loc]
#    4094         else:
# -> 4095             loc = index.get_loc(key)
#    4096
#    4097             if isinstance(loc, np.ndarray):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652             return self._engine.get_loc(casted_key)
#    3653         except KeyError as err:
# -> 3654             raise KeyError(key) from err
#    3655         except TypeError:
#    3656             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '2023'

# %%
fm_data_1.dtypes
# Out:
# month               object
# act_fcast           object
# 6010                object
# 6020                object
# 6030                object
# 6040                object
# 4010                object
# tot_rev             object
# tot_cogs            object
# cash                object
# op_cflow            object
# inv_cfloe           object
# fin_cflow           object
# net_chg_cash        object
# exp_salaries        object
# exp_marketing       object
# exp_facilities      object
# exp_telco           object
# exp_officeadmin     object
# exp_travel          object
# exp_profservices    object
# exp_randd           object
# exp_payrolltb       object
# exp_depamort        object
# exp_empdev          object
# exp_otherincexp     object
# exp_taxes           object
# headcount           object
# mrr                 object
# arr                 object
# cac                 object
# dtype: object
